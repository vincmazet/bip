# %% [markdown]
# (binry:conclusion)=
# # Conclusion
#
#
# <!-- top-hat : intéressant en nv de gris pour identifier des objets sur fond non uniforme (cf https://en.wikipedia.org/wiki/Top-hat_transform) -->
#
#
# <!-- Mathematical morphology gathers operators that work on the form of objects.
# We have studied some operators applied to binary images, but there are extensions of these techniques to grayscale images.
#
# The results given by the four main operators on binary images are listed in the following table.
#
# ````{list-table}
# :header-rows: 0
# :widths: 10 30
#
# * - ```{image} greece.png
#     ```
#   - **Original image**
#
# * - ```{image} greece-dilation.png
#     ```
#   - **Dilation** $\oplus$
#     * increases the size of objects (_e.g._ the islands are bigger)
#     * fills the small holes (_e.g._ the Gulf of Corinth
#       does not more exist after dilation)
#     * welds close objects (_e.g._ some islands are grouped into a larger island)
#
# * - ```{image} greece-erosion.png
#     ```
#   - **Erosion** $\ominus$
#     * decreases the size of objects (_e.g._ Crete is smaller)
#     * widens the holes (_e.g._ the Gulf of Corinth is bigger)
#     * separates the connected objects by a small bridge
#       (_e.g._ the Peloponnese and mainland Greece are now disconnected)
#     * removes small items (_e.g._ small islands have disappeared)
#
# * - ```{image} greece-opening.png
#     ```
#   - **Opening** $\circ$
#     * conserve the size of the objects (while they can be slightly distorted)
#     * removes small objects (_e.g._ small islands have disappeared)
#     * smoothes the contours (_e.g._ the coasts are no more jagged)
#
# * - ```{image} greece-closing.png
#     ```
#   - **Closing** $\bullet$
#     * conserve the size of the objects (while they can be slightly distorted)
#     * fills small holes (_e.g._ gulfs and lakes are removed)
#     * welds close shapes (_e.g._ some separated islands now form only one)
# ````
#
# **En morphologie mathématique, les images sont binaires et vues comme des ensembles constitués d'un fond (représenté en noir) sur lequel se trouvent des objets (représentés en blanc).  Nous avons introduit la notion de connexité et de voisinage de pixel. Les opérations élémentaires de la morphologie mathématiques effectuent des opérations sur une image binaire à partir d'un élément structurant (qui correspond également à une image binaire, souvent de petite taille). Ces opérations sont l'érosion et la dilatation, qui, une fois combinée, crée deux autres opérations : l'ouverture et la fermeture. Enfin, des opérateurs plus complexes peuvent être créés : [lister les outils vus en cours]. Il existe des adaptations de la morphologie mathématique aux images à niveau de gris [donner réfs].** -->
#
#
#
#
#
# ## References
#
# * (B:binary:Bloch2005)=
#   I. Bloch _et al._,
#   _Le traitement des images_
#   ([volume 1](https://perso.telecom-paristech.fr/bloch/ANIM/poly-anim-t1.pdf),
#   [volume 2](https://perso.telecom-paristech.fr/bloch/ANIM/poly-anim-t2.pdf)),
#   Polycopié du cours ANIM, Télécom-Paris, 2005.
